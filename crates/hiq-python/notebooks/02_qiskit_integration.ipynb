# %% [markdown]
# # HIQ + Qiskit Integration
#
# This notebook demonstrates seamless integration between HIQ and Qiskit, enabling:
# - Bi-directional circuit conversion (Qiskit ↔ HIQ)
# - Using HIQ as a Qiskit backend
# - Comparing compilation strategies
# - Leveraging HIQ's advanced compilation with Qiskit circuits
#
# ## Installation
#
# ```bash
# pip install arvak[qiskit]
# ```

# %% [markdown]
# ## Integration Check
#
# First, let's verify that the Qiskit integration is available.

# %%
import arvak

# Verify Qiskit integration is available
status = hiq.integration_status()
print("Available integrations:")
for name, info in status.items():
    icon = "✓" if info['available'] else "✗"
    print(f"  {icon} {name}: {info['packages']}")

# Check specifically for Qiskit
if 'qiskit' not in status or not status['qiskit']['available']:
    raise ImportError(
        "Qiskit integration not available. "
        "Install with: pip install qiskit>=1.0.0 qiskit-aer>=0.13.0"
    )

print("\n✓ Qiskit integration is available!")

# %% [markdown]
# ## Create a Qiskit Circuit
#
# Let's start with a standard Qiskit circuit.

# %%
from qiskit import QuantumCircuit

# Create a Bell state circuit in Qiskit
qc = QuantumCircuit(2, 2)
qc.h(0)
qc.cx(0, 1)
qc.measure(range(2), range(2))

print("Qiskit Circuit:")
print(qc.draw('text'))

# %% [markdown]
# ## Method 1: Direct Conversion via Integration API

# %%
# Get Qiskit integration
qiskit_integration = hiq.get_integration('qiskit')

# Convert Qiskit circuit to HIQ
hiq_circuit = qiskit_integration.to_hiq(qc)

print("HIQ Circuit:")
print(f"  Name: {hiq_circuit.name}")
print(f"  Qubits: {hiq_circuit.num_qubits}")
print(f"  Classical bits: {hiq_circuit.num_clbits}")
print(f"  Depth: {hiq_circuit.depth()}")
print(f"  Gate count: {hiq_circuit.size()}")

# %% [markdown]
# ## Method 2: Conversion via OpenQASM 3.0
#
# You can also convert circuits using OpenQASM 3.0 as an interchange format. This works even without the Qiskit integration installed.

# %%
from qiskit.qasm3 import dumps

# Export Qiskit circuit to QASM3
qasm_str = dumps(qc)
print("OpenQASM 3.0:")
print(qasm_str)
print("\n" + "="*60 + "\n")

# Import into HIQ
hiq_circuit_qasm = hiq.from_qasm(qasm_str)
print("HIQ Circuit (from QASM):")
print(f"  Qubits: {hiq_circuit_qasm.num_qubits}")
print(f"  Depth: {hiq_circuit_qasm.depth()}")

# %% [markdown]
# ## Convert HIQ Circuit Back to Qiskit

# %%
# Create a circuit in HIQ
hiq_original = hiq.Circuit.ghz(3)

# Convert to Qiskit
qiskit_circuit = qiskit_integration.from_hiq(hiq_original)

print("Converted to Qiskit:")
print(qiskit_circuit.draw('text'))

# %% [markdown]
# ## Use HIQ as a Qiskit Backend
#
# HIQ provides a Qiskit-compatible backend interface, allowing you to execute circuits through Qiskit's familiar API.

# %%
from hiq.integrations.qiskit import HIQProvider

# Get HIQ backends via Qiskit provider interface
provider = HIQProvider()
print("Available HIQ backends:")
for backend in provider.backends():
    print(f"  - {backend.name}")

# Select simulator
backend = provider.get_backend('sim')
print(f"\nSelected backend: {backend.name}")
print(f"  Qubits: {backend.num_qubits}")
print(f"  Basis gates: {backend.basis_gates}")

# %% [markdown]
# ## Execute Circuit on HIQ Backend
#
# **Note**: Backend execution is currently a mock implementation. For actual execution, use the HIQ CLI:
# ```bash
# hiq run circuit.qasm --backend sim --shots 1000
# ```

# %%
# Execute using standard Qiskit API
job = backend.run(qc, shots=1000)
result = job.result()
counts = result.get_counts()

print("Execution Results:")
for bitstring, count in sorted(counts.items()):
    bar = "█" * int(count / 10)
    print(f"  {bitstring}: {count:4d} {bar}")

# %% [markdown]
# ## Working with More Complex Circuits

# %%
# Create a more complex Qiskit circuit (GHZ-3)
qiskit_complex = QuantumCircuit(3, 3)
qiskit_complex.h(0)
qiskit_complex.cx(0, 1)
qiskit_complex.cx(1, 2)
qiskit_complex.measure(range(3), range(3))

print("Original Qiskit circuit:")
print(qiskit_complex.draw('text'))
print()

# %%
# Convert to HIQ
from qiskit.qasm3 import dumps
qasm_complex = dumps(qiskit_complex)
hiq_complex = hiq.from_qasm(qasm_complex)

print(f"HIQ GHZ-3 Circuit:")
print(f"  Depth: {hiq_complex.depth()}")
print(f"  Gates: {hiq_complex.size()}")
print(f"  Qubits: {hiq_complex.num_qubits}")
print("\nQASM representation:")
print(hiq.to_qasm(hiq_complex))

# %% [markdown]
# ## Configure Compilation for Hardware
#
# HIQ provides advanced compilation tools that can optimize circuits for specific hardware.

# %%
from arvak import CouplingMap, BasisGates, PropertySet, Layout

# Configure for IQM hardware
coupling_map = CouplingMap.star(5)
basis_gates = BasisGates.iqm()
layout = Layout.trivial(5)

props = PropertySet().with_target(coupling_map, basis_gates)
props.set_layout(layout)

print("IQM Hardware Configuration:")
print(f"  Topology: star with 5 qubits")
print(f"  Edges: {coupling_map.edges()}")
print(f"  Native gates: {basis_gates.gates()}")

# %% [markdown]
# ## Comparison: Different Backend Configurations

# %%
# Compare different hardware configurations
backends_config = [
    ("IQM", BasisGates.iqm(), CouplingMap.star(5)),
    ("IBM", BasisGates.ibm(), CouplingMap.linear(5)),
    ("Simulator", BasisGates.universal(), CouplingMap.full(5))
]

print("Backend Comparison:")
print("=" * 70)
for name, gates, topology in backends_config:
    print(f"\n{name}:")
    print(f"  Native gates: {gates.gates()}")
    print(f"  Connectivity: {topology.edges()}")
    print(f"  Qubits: {topology.num_qubits}")

# %% [markdown]
# ## Export for CLI Execution
#
# Save your circuit for execution with the HIQ CLI.

# %%
# Export circuit for CLI execution
output_qasm = hiq.to_qasm(hiq_complex)

# Save to file
with open("qiskit_circuit.qasm", "w") as f:
    f.write(output_qasm)

print("Circuit exported to qiskit_circuit.qasm")
print("\nTo execute:")
print("  $ hiq run qiskit_circuit.qasm --backend sim --shots 1000")
print("\nWith specific backend:")
print("  $ hiq run qiskit_circuit.qasm --backend iqm --shots 1000")

# %% [markdown]
# ## Summary
#
# This notebook demonstrated:
#
# 1. **Circuit Conversion**: Qiskit ↔ HIQ conversion via integration API or QASM
# 2. **Backend Interface**: Using HIQ as a Qiskit backend provider
# 3. **Compilation**: Configuring HIQ compilation for specific hardware
# 4. **Execution**: Running circuits through Qiskit's familiar API (or CLI for production)
#
# ## Next Steps
#
# - Explore **03_qrisp_integration.ipynb** for high-level quantum programming
# - Explore **04_cirq_integration.ipynb** for Google Cirq integration
# - Use the HIQ CLI for production execution on real hardware
# - Check out the HIQ dashboard for interactive circuit development
#
# ## Resources
#
# - HIQ Documentation: https://github.com/hiq-lab/HIQ
# - Qiskit Documentation: https://qiskit.org/documentation/
# - OpenQASM 3.0 Spec: https://openqasm.com/
